# %%
import numpy as np
import pandas as pd

# %%
xl = pd.ExcelFile('Table_1_03_A.xlsx')
xl.sheet_names
# Out:
# ['Table_1_03_A']

# %%
df = xl.parse(xl.sheet_names[0])

# %%
df
# Out:
#    Table 1.3.A. Utility Scale Facility Net Generation  \
# 0   by State, by Sector, January 2018 and 2017 (Th...
# 1                                                 NaN
# 2                                               \n \n
# 3                                            \n \n \n
# 4                          Census Division\nand State
# 5                                         New England
# 6                                         Connecticut
# 7                                               Maine
# 8                                       Massachusetts
# 9                                       New Hampshire
# 10                                       Rhode Island
# 11                                            Vermont
# 12                                    Middle Atlantic
# 13                                         New Jersey
# 14                                           New York
# 15                                       Pennsylvania
# ...

# %%
# df1 = df
df1 = df.iloc[4:]

# %%
df1
# Out:
#    Table 1.3.A. Utility Scale Facility Net Generation    Unnamed: 1  \
# 4                          Census Division\nand State  January 2018
# 5                                         New England          9590
# 6                                         Connecticut          3406
# 7                                               Maine          1102
# 8                                       Massachusetts          2713
# 9                                       New Hampshire          1729
# 10                                       Rhode Island           450
# 11                                            Vermont           190
# 12                                    Middle Atlantic         37147
# 13                                         New Jersey          5985
# 14                                           New York         12011
# 15                                       Pennsylvania         19151
# 16                                 East North Central         58072
# ...

# %%
new_header = df1.iloc[0]
new_header
# Out:
# Table 1.3.A. Utility Scale Facility Net Generation    Census Division\nand State
# Unnamed: 1                                                          January 2018
# Unnamed: 2                                                          January 2017
# Unnamed: 3                                                    Percentage\nChange
# Unnamed: 4                                                          January 2018
# Unnamed: 5                                                          January 2017
# Unnamed: 6                                                          January 2018
# Unnamed: 7                                                          January 2017
# Unnamed: 8                                                          January 2018
# Unnamed: 9                                                          January 2017
# Unnamed: 10                                                         January 2018
# Unnamed: 11                                                         January 2017
# ...

# %%
df2 = df1[1:]

# %%
df2
# Out:
#    Table 1.3.A. Utility Scale Facility Net Generation Unnamed: 1 Unnamed: 2  \
# 5                                         New England       9590       8730
# 6                                         Connecticut       3406       3236
# 7                                               Maine       1102        921
# 8                                       Massachusetts       2713       2659
# 9                                       New Hampshire       1729       1423
# 10                                       Rhode Island        450        318
# 11                                            Vermont        190        174
# 12                                    Middle Atlantic      37147      34018
# 13                                         New Jersey       5985       6133
# 14                                           New York      12011      10399
# 15                                       Pennsylvania      19151      17486
# ...

# %%
df2.columns = new_header 
df2
# Out:
# 4                          Census Division\nand State January 2018  \
# 5                                         New England         9590
# 6                                         Connecticut         3406
# 7                                               Maine         1102
# 8                                       Massachusetts         2713
# 9                                       New Hampshire         1729
# 10                                       Rhode Island          450
# 11                                            Vermont          190
# 12                                    Middle Atlantic        37147
# 13                                         New Jersey         5985
# 14                                           New York        12011
# 15                                       Pennsylvania        19151
# 16                                 East North Central        58072
# 17                                           Illinois        17526
# ...

# %%
df3 = df2.iloc[:, range(4)]

# %%
df3
# Out:
# 4                          Census Division\nand State January 2018  \
# 5                                         New England         9590
# 6                                         Connecticut         3406
# 7                                               Maine         1102
# 8                                       Massachusetts         2713
# 9                                       New Hampshire         1729
# 10                                       Rhode Island          450
# 11                                            Vermont          190
# 12                                    Middle Atlantic        37147
# 13                                         New Jersey         5985
# 14                                           New York        12011
# 15                                       Pennsylvania        19151
# 16                                 East North Central        58072
# 17                                           Illinois        17526
# ...

# %%
df3.columns
# Out:
# Index(['Census Division\nand State', 'January 2018', 'January 2017',
#        'Percentage\nChange'],
#       dtype='object', name=4)

# %%
mask = (df3['Census Division\nand State'] != 'Middle Atlantic') &\
(df3['Census Division\nand State'] !='East North Central') &\
(df3['Census Division\nand State'] !='West North Central') &\
(df3['Census Division\nand State'] !='South Atlantic') &\
(df3['Census Division\nand State'] !='East South Central') &\
(df3['Census Division\nand State'] !='West South Central') &\
(df3['Census Division\nand State'] !='Mountain') &\
(df3['Census Division\nand State'] !='Pacific Contiguous') &\
(df3['Census Division\nand State'] !='Pacific Noncontiguous') &\
(df3['Census Division\nand State'] !='U.S. Total')

# %%
df4=df3[mask].dropna(how='any')

# %%
df4
# Out:
# 4  Census Division\nand State January 2018 January 2017 Percentage\nChange
# 5                 New England         9590         8730              0.099
# 6                 Connecticut         3406         3236              0.053
# 7                       Maine         1102          921              0.197
# 8               Massachusetts         2713         2659               0.02
# 9               New Hampshire         1729         1423              0.215
# 10               Rhode Island          450          318              0.414
# 11                    Vermont          190          174              0.093
# 13                 New Jersey         5985         6133             -0.024
# 14                   New York        12011        10399              0.155
# 15               Pennsylvania        19151        17486              0.095
# 17                   Illinois        17526        16523              0.061
# ...

# %%
df4.rename(columns={'Census Division\nand State': 'state'}, inplace=True)
# df4.rename(index=str, columns={"": "state"})
df4
# Out:
# 4                  state January 2018 January 2017 Percentage\nChange
# 5            New England         9590         8730              0.099
# 6            Connecticut         3406         3236              0.053
# 7                  Maine         1102          921              0.197
# 8          Massachusetts         2713         2659               0.02
# 9          New Hampshire         1729         1423              0.215
# 10          Rhode Island          450          318              0.414
# 11               Vermont          190          174              0.093
# 13            New Jersey         5985         6133             -0.024
# 14              New York        12011        10399              0.155
# 15          Pennsylvania        19151        17486              0.095
# 17              Illinois        17526        16523              0.061
# 18               Indiana        11193         9511              0.177
# ...

# %%
df5 = df4[['state', 'January 2018']]
df5
# Out:
# 4                  state January 2018
# 5            New England         9590
# 6            Connecticut         3406
# 7                  Maine         1102
# 8          Massachusetts         2713
# 9          New Hampshire         1729
# 10          Rhode Island          450
# 11               Vermont          190
# 13            New Jersey         5985
# 14              New York        12011
# 15          Pennsylvania        19151
# 17              Illinois        17526
# 18               Indiana        11193
# 19              Michigan        11057
# 20                  Ohio        12117
# 21             Wisconsin         6180
# 23                  Iowa         5828
# 24                Kansas         4702
# 25             Minnesota         6068
# 26              Missouri         8057
# 27              Nebraska         3399
# 28          North Dakota         4108
# 29          South Dakota         1075
# 31              Delaware          580
# 32  District of Columbia            7
# ...

# %%
states_hash ={
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District Of Columbia': 'DC',
    'Federated States Of Micronesia': 'FM',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Marshall Islands': 'MH',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands': 'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
  }

# %%
df5['state'].map(states_hash)
# Out:
# 5     NaN
# 6      CT
# 7      ME
# 8      MA
# 9      NH
# 10     RI
# 11     VT
# 13     NJ
# 14     NY
# 15     PA
# 17     IL
# 18     IN
# 19     MI
# 20     OH
# 21     WI
# 23     IA
# 24     KS
# 25     MN
# 26     MO
# 27     NE
# 28     ND
# 29     SD
# 31     DE
# 32    NaN
# 33     FL
# 34     GA
# 35     MD
# 36     NC
# 37     SC
# 38     VA
# 39     WV
# 41     AL
# 42     KY
# 43     MS
# 44     TN
# 46     AR
# 47     LA
# 48     OK
# 49     TX
# 51     AZ
# 52     CO
# 53     ID
# 54     MT
# 55     NV
# 56     NM
# 57     UT
# 58     WY
# 60     CA
# 61     OR
# 62     WA
# 64     AK
# 65     HI
# Name: state, dtype: object

# %%
df5
# Out:
# 4                  state January 2018
# 5            New England         9590
# 6            Connecticut         3406
# 7                  Maine         1102
# 8          Massachusetts         2713
# 9          New Hampshire         1729
# 10          Rhode Island          450
# 11               Vermont          190
# 13            New Jersey         5985
# 14              New York        12011
# 15          Pennsylvania        19151
# 17              Illinois        17526
# 18               Indiana        11193
# 19              Michigan        11057
# 20                  Ohio        12117
# 21             Wisconsin         6180
# 23                  Iowa         5828
# 24                Kansas         4702
# 25             Minnesota         6068
# 26              Missouri         8057
# 27              Nebraska         3399
# 28          North Dakota         4108
# 29          South Dakota         1075
# 31              Delaware          580
# 32  District of Columbia            7
# ...

# %%
df4
# Out:
# Census Division
# and State Census Division\nand State January 2018  \
# 5                                        New England         9590
# 6                                        Connecticut         3406
# 7                                              Maine         1102
# 8                                      Massachusetts         2713
# 9                                      New Hampshire         1729
# 10                                      Rhode Island          450
# 11                                           Vermont          190
# 13                                        New Jersey         5985
# 14                                          New York        12011
# 15                                      Pennsylvania        19151
# 17                                          Illinois        17526
# 18                                           Indiana        11193
# 19                                          Michigan        11057
# ...

# %%
df4.columns.rename('Census Division\nand State', 'state')

# %%
df4
# Out:
# Census Division
# and State Census Division\nand State January 2018  \
# 5                                        New England         9590
# 6                                        Connecticut         3406
# 7                                              Maine         1102
# 8                                      Massachusetts         2713
# 9                                      New Hampshire         1729
# 10                                      Rhode Island          450
# 11                                           Vermont          190
# 13                                        New Jersey         5985
# 14                                          New York        12011
# 15                                      Pennsylvania        19151
# 17                                          Illinois        17526
# 18                                           Indiana        11193
# 19                                          Michigan        11057
# ...
